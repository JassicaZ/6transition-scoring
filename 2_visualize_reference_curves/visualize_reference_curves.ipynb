# %% [markdown]
# # 6-transition reference curve

# %% [markdown]
# ### The Z-score reference table for the age-6 transition is provided in this repository and can be loaded using:

# %%
import pandas as pd

df = pd.read_csv("./data/reference_curve.csv")
df
# Out:
#        age        -2        -1         0         1         2
# 0      0.0  0.343724  0.382636  0.405031  0.427491  0.466827
# 1      0.5  0.348688  0.388110  0.410971  0.433904  0.473797
# 2      1.0  0.353623  0.393549  0.416878  0.440287  0.480732
# 3      1.5  0.358517  0.398941  0.422739  0.446626  0.487617
# 4      2.0  0.363363  0.404276  0.428543  0.452909  0.494439
# ..     ...       ...       ...       ...       ...       ...
# 196   98.0  0.467809  0.535237  0.590408  0.651134  0.744296
# 197   98.5  0.468335  0.536213  0.591455  0.652288  0.746287
# 198   99.0  0.468875  0.537205  0.592520  0.653459  0.748304
# 199   99.5  0.469422  0.538210  0.593597  0.654642  0.750342
# 200  100.0  0.469974  0.539222  0.594680  0.655829  0.752393
#
# [201 rows x 6 columns]

# %% [markdown]
# ### The following example shows how to visualize individual scores on the reference curve:

# %%
# Load the transition scores from the previous step
df_score4CD= pd.read_csv("../1_calculate_6transition_score/results/example/transition_score/transition_scores.csv")

# %%
df_score4CD
# Out:
#      sample    age  6_transition_score
# 0  gi_sc_24   8.92            0.511989
# 1  gi_sc_27   7.92            0.594565
# 2  gi_sc_31  10.33            0.608358
# 3  gi_sc_39  17.08            0.598721
# 4  gi_sc_52  18.00            0.578084
# 5  gi_sc_55  16.42            0.655793
# 6  gi_sc_60  17.08            0.569517

# %%
import matplotlib.pyplot as plt

df=df[df['age']<=21]
x = df["age"]

# 创建画布
plt.figure(figsize=(8, 6))

# 依次画每条z-score曲线
for col in df.columns[1:]:
    plt.plot(x, df[col], label=f"z={col}")

#画个体点
plt.scatter(
    df_score4CD["age"],
    df_score4CD["6_transition_score"],
    color="black",
    s=20,
    alpha=0.6,
    label="Individuals from the CD cohort"
)

# 设置标签
plt.xlabel("Age")
plt.ylabel("Score")
plt.legend(title="Z-score")
plt.tight_layout()

plt.show()
